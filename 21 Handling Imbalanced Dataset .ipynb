# %% [markdown]
# ## Handling imbalanced dataset in Customer Churn Prediction
#
# Customer churn prediction is to measure why customers are leaving a business. In this notebook we will be looking at customer churn in telecom business. We will build a deep learning model to predict the churn and use precision, recall, f1-score to measure performance of our model. We will then handle imbalance in data using various techniques and imporve f1-score.
#
# <b> Challenge faced with imbalanced data </b>
#
# One of the main challenges faced by the utility industry today is electricity theft. Electricity theft is the third largest form of theft worldwide. Utility companies are increasing turning towards advanced analystics and machine learning algorithms to identify consumption patterns that indicate theft.
#
# However, one of the biggest stumbling blocks is the humongous data and its distribution. Fraudulent transactions are significantly lower than normal healthy transactions i.e accounting it to around 1-2% of the total number of observations. The ask it to imporve identification of the rare minority class as opposed to achieving higher overall accuracy.
#
# Machine Learning algorithms tend to produce unsatisfactory classifiers when faced with imbalanced datasets. For any imbalanced data set, if the event to be predicted belongs to the minority class and the event rate is less than 5%, it is usually referred to as a rare event.
#
# <b> Example of imbalanced data </b>
#
# Let's understand this with the help of an example.
#
# Ex:  In an utilities fraud detection data set you have the following data:
#
# - Total Observations : 1000
# - Fraudulent Observations: 20
# - Non Fraudulent Observations: 980
# - Event Rate : 2%
#
# <b> Challenges with standard Machine Learning technqiues </b>
#
# The conventional model evaluation methods do not accurately measure model performance when faced with imbalanced datasets.
#
# Standard classifier algorithms like Decision Tree and Logistic Regression have a bias towards classes which have a number of instances. They tend to only predict the majority class data. The features of the minority class are treated as noise and are often ignored. Thus, there is a high probability of missclassification of the minority class as compared to the majortiy class.
#
# Evaluation of a classification algorithm performance is measured by the Confusion Matrix which contains information about the actual and the predicted class.

# %% [markdown]
# ![ICP1.webp](attachment:ICP1.webp)

# %% [markdown]
#   <b> Accuracy of a model = (TP+TN) / (TP+FN+FP+TN) </b>
#
#
# However, while working in an imbalanced domain accuracy is not an appropriate measure to evaluate model performance. For eg: A classifier which achieves an accuracy of 98% with an event rate of 2% is not accurate, it is classifies all instances as the majority class. And eliminates the 2% minority class observations as noise.
#
# <b> Examples of imbalanced data </b>
#
# Thus, to sum it up, while trying to resolve specific business challenges with imbalanced data sets, the classifiers produced by standard machine learning algorithms might not give accurate results. Apart from fraudulent transactions, other examples of a common business problem with imbalanced dataset are:
#
# - Datasets to identify customer churn where a vast majority of customers will continue using the service. Specifically, Telecommunication companies where Churn Rate is lower than 2 %.
# - Data sets to identify rare diseases in medical diagnostics etc.
# - Natural Disaster like Earthquakes

# %% [markdown]
# ## Approach to handling Imbalanced Data
#
# .
#
# ### 1. Data Level approach: Resampling Techniques
#
# Dealing with imbalanced dataset entails strategies such as improving classification algorithms or balancing classes in the training data (data preprocessing) before providing the data as input to the machine learning algorithms. The later technqiue is preferred as it has wider application.
#
# The main objective of balancing classes is to either increasing the frequency of the minority class or decreasing the frequency of the majority class. This is done in order to obtain approximately the same number of instances for both the classes. Let us look at a few resampling technqiues.

# %% [markdown]
# ### 2. Random Under-Sampling
#
# Random Undersampling aims to balance class distribution by randomly eliminating majority class examples. This is done until the majority and minority class instances are balanced out.
#
# - Total Observations = 100
# - Fraudulent Observations = 20
# - Non Fraudulent Observations = 980
# - Event Rate : 2%
#
# In this case we are taking 10% samples without replacement from Non Fraud instances. And combining them with Fraud instances.
#
# - Non Fraudulent Observations after random under sampling = 10 % of 980 = 98
# - Total Observations after combining them with Fraudulent observations = 20 + 98 = 118
# - Event Rate for the new dataset after under samplign = 20/118 = 17%
#
# <b> Advantages: </b>
# - It can help improve run time and storage problems by reducing the number of training data samples when the training data set is huge.
#
#
# <b> Disadvantage: </b>
# - It can discard potentially useful information which could be important for building rule classifiers.
# - THe sample chosen by random under sampling may be a biased sample. And it will not be an accurate representative of the population. Thereby, resulting in accurate results with the actual test data set.

# %% [markdown]
# ### 3. Random Over-Sampling
#
# Over-Sampling increases the number of instances in the minority class by randomly replicating them in order to present a higher representation of the minority class in the sample.
#
# - Total Observations = 1000
# - Fraudulent Observations = 20
# - Non Fraudulent Observations = 980
# - Event Rate : 2%
#
#
# In this case we are replicating 20 fraud observations 20 times.
#
# - Non Fraudulent Observations = 980
# - Fraudulent Observations after replicating the minority class observationis = 400
# - Total observations in the new data set after oversamplign = 1380
# - Event Rate for the new data set after under sampling = 400 / 1380 = 29%
#
# <b> Advantages: </b>
#
# - Unlike under sampling this method leads to no information loss.
# - Outperforms under sampling
#
# <b> Disadvantages : </b>
# - It increases the likelihood of overfitting since it replicates the minority class events.

# %% [markdown]
# ### 4. Cluster-Based Over Sampling
#
# In this case, the K-means clustering algorithm is independently applied to minority and majority class instances. This is to identify clusters in the dataset. Subsequently, each cluster is oversampled such that all the clusters of the same class have an equal number of instances and all classes have the same size.
#
# - Total Observations : 100
# - Fraudulent Observations : 20
# - Non Fraudulent Observations : 980
# - Event Rate : 2%
#
# <b> Majority Class Clusters </b>
#
# - Cluster 1: 150 Observations
# - Cluster 2: 120 Observations
# - Cluster 3: 230 Observations
# - Cluster 4: 200 Observations
# - Cluster 5: 150 Observations
# - Cluster 6: 130 Observations
#
# <b> Minority Class Clusters </b>
# - Cluster 1: 8 Observations
# - Cluster 2: 12 Observations
#
#
# <b> After oversampling of each cluster, all clusters of the same class contains the same number of observations </b>
#
# <b> Majority Class Cluster</b>
# - Cluster 1: 170 Observations
# - CLuster 2: 170 Observations
# - Cluster 3: 170 Observations
# - Cluster 4: 170 Observations
# - Cluster 5: 170 Observations
# - Cluster 6: 170 Observations
#
# <b> Minority Class Clusters </b>
#
# - Cluster 1: 250 Observations
# - Cluster 2: 250 Observations
#
# <b> Advantages </b>
#
# - This clustering technqiue helps overcome the challenges between class imbalance. Where the number of examples representing positive class differs from the number of examples representing a negative class.
#
# - Also, overcome challenges within class imbalance, where a class is composed of different sub clusters. And each sub cluster does not contain the same number of examples.
#
# <b> Disadvantages </b>
#
# - The main drawback of this algorithm, like most oversampling techniques is the possibility of over-fitting the trainng data.

# %% [markdown]
# ### 4. Informed Over Sampling: Synthetic Minority Over-Sampling Technique for imbalanced data.
#
# This technique is followed to avoid overfitting which occurs when exact replicas of minority instances are added to the main dataset. A subset of data is taken from the minority class as an example and then new synthetic similar instances are created. These snthetic instances are then added to the original dataset. The new dataset is used as a sample to train the classification models.
#
# - Total Observations : 1000
#
# - Fraud Observations: 20
#
# - Non-Fraud Observations : 980
#
# Event Rate = 2%
#
# A sample of instances is taken from the minority class and similar synthetic instances are generated 20 times.
#
# Post generations of synthetic instances, the following dataset is created:
#
# - Minority Class (Fraudulent Observations) = 300
# - Majority Class (Non-Fraudulent Observations) = 980
#
# Event Rate = 300/ 1280 = 23.4 %
#
# <b> Advantages </b>
#
# - Mitigates the problem of overfitting caused by random oversampling as synthetic examples are generated rather than replication of instances
# - No loss of useful information
#
# <b> Disadvantages </b>
# - While generating synthetic examples SMOTE does not take into consideration neighboring examples from other classes. This can result in increase in overlapping of classes and can introduce additional noise
# - SMOTE is not very effective for high dimensional data

# %% [markdown]
# ### Modified synthetic minority oversampling technique (MSMOTE) for imbalanced data
#
# It is a modified version of SMOTE. SMOTE does not consider the underlying distribution of the minority class and latent noises in the dataset. To improve the performance of SMOTE a modified method MSMOTE is used.
#
# This algorithm classifies the samples of minority classes into 3 distinct groups – Security/Safe samples, Border samples, and latent nose samples. This is done by calculating the distances among samples of the minority class and samples of the training data.
#
# Security samples are those data points which can improve the performance of a classifier. While on the other hand, noise are the data points which can reduce the performance of the classifier.  The ones which are difficult to categorize into any of the two are classified as border samples.
#
# While the basic flow of MSOMTE is the same as that of SMOTE (discussed in the previous section).  In MSMOTE the strategy of selecting nearest neighbors is different from SMOTE. The algorithm randomly selects a data point from the k nearest neighbors for the security sample, selects the nearest neighbor from the border samples and does nothing for latent noise.

# %% [markdown]
# ## Coding

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# <b> Load the Data </b>

# %%
df = pd.read_csv('customer_churn.csv')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 47    7760-OYPDY  Female              0      No         No       2
# 4877  4973-RLZVI  Female              0      No         No      30
# 2987  3769-MHZNV  Female              0     Yes        Yes      33
# 2329  2972-YDYUW  Female              0      No         No      57
# 5235  4299-SIMNS    Male              0      No         No       9
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 47            Yes            No     Fiber optic                   No  ...
# 4877          Yes            No             DSL                  Yes  ...
# 2987          Yes            No              No  No internet service  ...
# 2329          Yes           Yes     Fiber optic                   No  ...
# 5235          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 47                     No                   No                  Yes
# 4877                  Yes                  Yes                  Yes
# 2987  No internet service  No internet service  No internet service
# 2329                   No                  Yes                   No
# 5235                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 47                     No  Month-to-month              Yes
# 4877                   No        One year               No
# 2987  No internet service        Two year               No
# 2329                  Yes        One year               No
# 5235                   No  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 47           Electronic check          80.65        144.15   Yes
# 4877  Credit card (automatic)          74.65        2308.6    No
# 2987             Mailed check          20.10        670.35    No
# 2329         Electronic check          94.70       5468.95    No
# 5235         Electronic check          81.15        784.45    No
#
# [5 rows x 21 columns]

# %%
df.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# <b> First of all, drop customerID column as it is of no use

# %%
df.drop('customerID', axis = 1, inplace = True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# <b> Quick glance at above makes me realize that TotalCharges should be float but it is an object. Let's check what's goind on with this column

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %% [markdown]
# <b>Let's convert it to numbers

# %%
pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488].TotalCharges
# Out:
# ' '

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (7032, 20)

# %% [markdown]
# <b> Remove rows with spaces in TotalCharges

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\basto\anaconda3\envs\tfgpu\lib\site-packages\pandas\core\generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
df1[df1.Churn == 'No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %%
def print_unique_col_values(df):
    for column in df:
        if df[column].dtypes== 'object':
            print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# <b> Some of the columns have no internet service or no phone service, that can be replaced with a simple No

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\basto\anaconda3\envs\tfgpu\lib\site-packages\pandas\core\frame.py:4521: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# <b> Convert Yes and No to 1 or 0

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

for col in yes_no_columns:
    df1[col].replace({'Yes':1,'No': 0}, inplace = True)
# Out:
# C:\Users\basto\anaconda3\envs\tfgpu\lib\site-packages\pandas\core\series.py:4506: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# <b> One hot encoding for categorical columns

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4578       1              0        0           0      10             1
# 5344       0              0        0           1      71             1
# 646        0              0        0           0       1             1
# 1136       1              0        1           1      63             1
# 3473       0              0        1           0      42             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4578              0               0             0                 0  ...
# 5344              0               1             1                 1  ...
# 646               0               0             0                 0  ...
# 1136              0               0             0                 0  ...
# 3473              1               0             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 4578                    1                            0                   0
# 5344                    1                            0                   0
# 646                     1                            0                   0
# 1136                    0                            0                   1
# 3473                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 4578                        1                  0                  0
# 5344                        0                  0                  1
# 646                         1                  0                  0
# 1136                        0                  0                  1
# 3473                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 4578                                        0
# 5344                                        0
# 646                                         0
# 1136                                        0
# 3473                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 4578                                      0                               0
# 5344                                      1                               0
# 646                                       0                               0
# 1136                                      1                               0
# 3473                                      0                               0
#
#       PaymentMethod_Mailed check
# 4578                           1
# 5344                           0
# 646                            1
# 1136                           0
# 3473                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %% [markdown]
# <b> Train test split

# %%
X = df2.drop('Churn',axis='columns')
y = testLabels = df2.Churn.astype(np.float32)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0.0    4130
# 1.0    1495
# Name: Churn, dtype: int64

# %%
y.value_counts()
# Out:
# 0.0    5163
# 1.0    1869
# Name: Churn, dtype: int64

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 684        1              0        0           0  0.000000             1
# 2446       1              0        0           0  0.239437             1
# 1680       0              0        1           1  0.774648             1
# 2220       0              0        1           0  1.000000             1
# 2842       1              0        0           0  0.042254             0
# 5131       1              0        1           0  0.605634             1
# 4372       0              0        1           1  0.000000             1
# 4687       0              0        1           0  0.295775             1
# 2385       1              0        0           1  0.028169             0
# 6773       0              1        1           0  0.507042             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 684               0               0             0                 0  ...
# 2446              1               0             1                 0  ...
# 1680              1               0             0                 0  ...
# 2220              0               1             1                 0  ...
# 2842              0               1             0                 1  ...
# 5131              1               0             0                 0  ...
# 4372              0               0             0                 0  ...
# 4687              0               0             0                 1  ...
# 2385              0               0             1                 0  ...
# 6773              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 684                     0                            1                   0
# 2446                    0                            1                   0
# 1680                    0                            0                   1
# 2220                    1                            0                   0
# 2842                    1                            0                   0
# 5131                    0                            1                   0
# 4372                    0                            0                   1
# 4687                    0                            1                   0
# 2385                    1                            0                   0
# 6773                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 684                         1                  0                  0
# 2446                        1                  0                  0
# 1680                        0                  1                  0
# 2220                        0                  0                  1
# 2842                        1                  0                  0
# 5131                        1                  0                  0
# 4372                        1                  0                  0
# 4687                        1                  0                  0
# 2385                        1                  0                  0
# 6773                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 684                                         0
# 2446                                        0
# 1680                                        0
# 2220                                        1
# 2842                                        0
# 5131                                        0
# 4372                                        1
# 4687                                        0
# 2385                                        0
# 6773                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 684                                       0                               0
# 2446                                      1                               0
# 1680                                      0                               0
# 2220                                      0                               0
# 2842                                      0                               0
# 5131                                      0                               1
# 4372                                      0                               0
# 4687                                      1                               0
# 2385                                      0                               0
# 6773                                      0                               1
#
#       PaymentMethod_Mailed check
# 684                            1
# 2446                           0
# 1680                           1
# 2220                           0
# 2842                           1
# 5131                           0
# 4372                           0
# 4687                           0
# 2385                           1
# 6773                           0
#
# [10 rows x 26 columns]

# %% [markdown]
# <b> Build a model (ANN) in tensorflow/keras

# %%
from tensorflow_addons import losses

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(26, input_dim=26, activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    
    if weights == -1:
        model.fit(X_train, y_train, epochs=100)
    else:
        model.fit(X_train, y_train, epochs=100, class_weight = weights)
    
    print(model.evaluate(X_test, y_test))
    
    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)
    
    print("Classification Report: \n", classification_report(y_test, y_preds))
    
    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 2s 3ms/step - loss: 0.5500 - accuracy: 0.7406
# Epoch 2/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7833
# Epoch 3/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4339 - accuracy: 0.7936
# Epoch 4/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.7953
# Epoch 5/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8050
# Epoch 6/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.7929
# Epoch 7/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4153 - accuracy: 0.8012
# Epoch 8/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8086
# Epoch 9/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8061
# Epoch 10/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4056 - accuracy: 0.8058
# Epoch 11/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8050
# Epoch 12/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4105 - accuracy: 0.8027
# Epoch 13/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4070 - accuracy: 0.8115
# Epoch 14/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3968 - accuracy: 0.8147
# Epoch 15/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4040 - accuracy: 0.8135
# Epoch 16/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8159
# Epoch 17/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3982 - accuracy: 0.8144
# Epoch 18/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4070 - accuracy: 0.8009
# Epoch 19/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3843 - accuracy: 0.8186
# Epoch 20/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3880 - accuracy: 0.8234
# Epoch 21/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3889 - accuracy: 0.8149
# Epoch 22/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3954 - accuracy: 0.8073
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3872 - accuracy: 0.8153
# Epoch 24/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8211
# Epoch 25/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3945 - accuracy: 0.8050
# Epoch 26/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3919 - accuracy: 0.8153
# Epoch 27/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3907 - accuracy: 0.8103
# Epoch 28/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3913 - accuracy: 0.8138
# Epoch 29/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8091
# Epoch 30/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3883 - accuracy: 0.8046
# Epoch 31/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3922 - accuracy: 0.8126
# Epoch 32/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3846 - accuracy: 0.8220
# Epoch 33/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8101
# Epoch 34/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3910 - accuracy: 0.8069
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8216
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8236
# Epoch 37/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8222
# Epoch 38/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3899 - accuracy: 0.8206
# Epoch 39/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3811 - accuracy: 0.8186
# Epoch 40/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3805 - accuracy: 0.8212
# Epoch 41/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3772 - accuracy: 0.8227
# Epoch 42/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3767 - accuracy: 0.8229
# Epoch 43/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3951 - accuracy: 0.8127
# Epoch 44/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3921 - accuracy: 0.8146
# Epoch 45/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3690 - accuracy: 0.8241
# Epoch 46/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3822 - accuracy: 0.8158
# Epoch 47/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3692 - accuracy: 0.8209
# Epoch 48/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3588 - accuracy: 0.8315
# Epoch 49/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3838 - accuracy: 0.8158
# Epoch 50/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3784 - accuracy: 0.8181
# Epoch 51/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3719 - accuracy: 0.8229
# Epoch 52/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3849 - accuracy: 0.8180
# Epoch 53/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3742 - accuracy: 0.8275
# Epoch 54/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8234
# Epoch 55/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3826 - accuracy: 0.8245
# Epoch 56/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3793 - accuracy: 0.8248
# Epoch 57/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3813 - accuracy: 0.8206
# Epoch 58/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3762 - accuracy: 0.8213
# Epoch 59/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3816 - accuracy: 0.8166
# Epoch 60/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3711 - accuracy: 0.8256
# Epoch 61/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3756 - accuracy: 0.8221
# Epoch 62/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3712 - accuracy: 0.8294
# Epoch 63/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3772 - accuracy: 0.8143
# Epoch 64/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3610 - accuracy: 0.8271
# Epoch 65/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3674 - accuracy: 0.8225
# Epoch 66/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3705 - accuracy: 0.8261
# Epoch 67/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3756 - accuracy: 0.8202
# Epoch 68/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3599 - accuracy: 0.8293
# Epoch 69/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3655 - accuracy: 0.8255
# Epoch 70/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3751 - accuracy: 0.8245
# Epoch 71/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.8361
# Epoch 72/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3587 - accuracy: 0.8321
# Epoch 73/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8256
# Epoch 74/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3589 - accuracy: 0.8256
# Epoch 75/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3584 - accuracy: 0.8264
# Epoch 76/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3690 - accuracy: 0.8266
# Epoch 77/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3670 - accuracy: 0.8227
# Epoch 78/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3668 - accuracy: 0.8276
# Epoch 79/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3600 - accuracy: 0.8283
# Epoch 80/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3618 - accuracy: 0.8299
# Epoch 81/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.8359
# Epoch 82/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3644 - accuracy: 0.8237
# Epoch 83/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3716 - accuracy: 0.8199
# Epoch 84/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3618 - accuracy: 0.8311
# Epoch 85/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3534 - accuracy: 0.8304
# Epoch 86/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3515 - accuracy: 0.8377
# Epoch 87/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3534 - accuracy: 0.8304
# Epoch 88/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8314
# Epoch 89/100
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3521 - accuracy: 0.8327
# Epoch 90/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3554 - accuracy: 0.8363
# Epoch 91/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3573 - accuracy: 0.8262
# Epoch 92/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3591 - accuracy: 0.8260
# Epoch 93/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3342 - accuracy: 0.8419
# Epoch 94/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.8252
# Epoch 95/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3487 - accuracy: 0.8370
# Epoch 96/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.8384
# Epoch 97/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3441 - accuracy: 0.8383
# Epoch 98/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3521 - accuracy: 0.8348
# Epoch 99/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3518 - accuracy: 0.8326
# Epoch 100/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8394
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4774 - accuracy: 0.7804
# [0.4774087071418762, 0.7803837656974792]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.82      0.90      0.86      1033
#          1.0       0.62      0.45      0.52       374
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.67      0.69      1407
# weighted avg       0.77      0.78      0.77      1407

# %% [markdown]
# # Techniques to Handle Imbalanced Data

# %% [markdown]
# ## Method 1: Undersampling

# %%
# Class count
count_class_0, count_class_1 = df1.Churn.value_counts()

# Divide by class
df_class_0 = df2[df2['Churn'] == 0]
df_class_1 = df2[df2['Churn'] == 1]

# %%
# Undersample 0-class and concat the DataFrames of both class
df_class_0_under = df_class_0.sample(count_class_1)
df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_test_under.Churn.value_counts())
# Out:
# Random under-sampling:
# 0    1869
# 1    1869
# Name: Churn, dtype: int64

# %%
X = df_test_under.drop('Churn',axis='columns')
y = df_test_under['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0    1495
# 1    1495
# Name: Churn, dtype: int64

# %% [markdown]
# <b> Printing Classification in the last, Scroll down till the last epoch to watch the classification report

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 3ms/step - loss: 0.6617 - accuracy: 0.5970
# Epoch 2/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5325 - accuracy: 0.7416
# Epoch 3/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4801 - accuracy: 0.7616
# Epoch 4/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4982 - accuracy: 0.7488
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4861 - accuracy: 0.7561
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7747
# Epoch 7/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4797 - accuracy: 0.7617
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4572 - accuracy: 0.7708
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4878 - accuracy: 0.7606
# Epoch 10/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4533 - accuracy: 0.7768
# Epoch 11/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7615
# Epoch 12/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.7680
# Epoch 13/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.7851
# Epoch 14/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.7705
# Epoch 15/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.7915
# Epoch 16/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4569 - accuracy: 0.7866
# Epoch 17/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4615 - accuracy: 0.7652
# Epoch 18/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4665 - accuracy: 0.7765
# Epoch 19/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4543 - accuracy: 0.7844
# Epoch 20/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4677 - accuracy: 0.7726
# Epoch 21/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.7832
# Epoch 22/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.7861
# Epoch 23/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4472 - accuracy: 0.7818
# Epoch 24/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4567 - accuracy: 0.7818
# Epoch 25/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4514 - accuracy: 0.7777
# Epoch 26/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4548 - accuracy: 0.7772
# Epoch 27/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4591 - accuracy: 0.7743
# Epoch 28/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4319 - accuracy: 0.7993
# Epoch 29/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4666 - accuracy: 0.7786
# Epoch 30/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4302 - accuracy: 0.7994
# Epoch 31/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.7996
# Epoch 32/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7991
# Epoch 33/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4480 - accuracy: 0.7800
# Epoch 34/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.7964
# Epoch 35/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7868
# Epoch 36/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4474 - accuracy: 0.7849
# Epoch 37/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4370 - accuracy: 0.7907
# Epoch 38/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.7942
# Epoch 39/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.7894
# Epoch 40/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4240 - accuracy: 0.8048
# Epoch 41/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4359 - accuracy: 0.7876
# Epoch 42/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4264 - accuracy: 0.7997
# Epoch 43/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.7879
# Epoch 44/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4411 - accuracy: 0.7926
# Epoch 45/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4400 - accuracy: 0.7885
# Epoch 46/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4368 - accuracy: 0.7885
# Epoch 47/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4140 - accuracy: 0.8074
# Epoch 48/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4360 - accuracy: 0.7831
# Epoch 49/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4358 - accuracy: 0.7896
# Epoch 50/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4172 - accuracy: 0.7974
# Epoch 51/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7772
# Epoch 52/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4040 - accuracy: 0.8140
# Epoch 53/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4297 - accuracy: 0.7878
# Epoch 54/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4332 - accuracy: 0.7882
# Epoch 55/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8120
# Epoch 56/100
# 94/94 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.80 - 0s 3ms/step - loss: 0.4245 - accuracy: 0.8029
# Epoch 57/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8008
# Epoch 58/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4246 - accuracy: 0.8009
# Epoch 59/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4252 - accuracy: 0.7957
# Epoch 60/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4148 - accuracy: 0.8053
# Epoch 61/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4122 - accuracy: 0.8074
# Epoch 62/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4187 - accuracy: 0.8060
# Epoch 63/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.7993
# Epoch 64/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4165 - accuracy: 0.7973
# Epoch 65/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8033
# Epoch 66/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8104
# Epoch 67/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4228 - accuracy: 0.8094
# Epoch 68/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8160
# Epoch 69/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.8028
# Epoch 70/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4285 - accuracy: 0.7897
# Epoch 71/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4235 - accuracy: 0.7910
# Epoch 72/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3994 - accuracy: 0.8167
# Epoch 73/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8012
# Epoch 74/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.8007
# Epoch 75/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4024 - accuracy: 0.8016
# Epoch 76/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4148 - accuracy: 0.8061
# Epoch 77/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8104
# Epoch 78/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3867 - accuracy: 0.8243
# Epoch 79/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4021 - accuracy: 0.8198
# Epoch 80/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.8195
# Epoch 81/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.7964
# Epoch 82/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3954 - accuracy: 0.8133
# Epoch 83/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3975 - accuracy: 0.8120
# Epoch 84/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.8169
# Epoch 85/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8092
# Epoch 86/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4044 - accuracy: 0.8120
# Epoch 87/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8188
# Epoch 88/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.8160
# Epoch 89/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3910 - accuracy: 0.8230
# Epoch 90/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8133
# Epoch 91/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.8135
# Epoch 92/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.8197
# Epoch 93/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 0.8208
# Epoch 94/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3899 - accuracy: 0.8216
# Epoch 95/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3860 - accuracy: 0.8167
# Epoch 96/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3945 - accuracy: 0.8114
# Epoch 97/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3899 - accuracy: 0.8169
# Epoch 98/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8210
# Epoch 99/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3784 - accuracy: 0.8293
# Epoch 100/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8225
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5398 - accuracy: 0.7447
# [0.5397891998291016, 0.7446523904800415]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75       374
#            1       0.75      0.73      0.74       374
#
#     accuracy                           0.74       748
#    macro avg       0.74      0.74      0.74       748
# weighted avg       0.74      0.74      0.74       748

# %% [markdown]
# ## Method 2: OverSampling

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over.Churn.value_counts())
# Out:
# Random over-sampling:
# 0    5163
# 1    5163
# Name: Churn, dtype: int64

# %%
X = df_test_over.drop('Churn',axis='columns')
y = df_test_over['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0    4130
# 1    4130
# Name: Churn, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.5979 - accuracy: 0.6551
# Epoch 2/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4938 - accuracy: 0.7629
# Epoch 3/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4888 - accuracy: 0.7698
# Epoch 4/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4888 - accuracy: 0.7656
# Epoch 5/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4838 - accuracy: 0.7624
# Epoch 6/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4747 - accuracy: 0.7726
# Epoch 7/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4551 - accuracy: 0.7863
# Epoch 8/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4751 - accuracy: 0.7788
# Epoch 9/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4629 - accuracy: 0.7764
# Epoch 10/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4579 - accuracy: 0.7784
# Epoch 11/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4623 - accuracy: 0.7842
# Epoch 12/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4666 - accuracy: 0.7808
# Epoch 13/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4570 - accuracy: 0.7832
# Epoch 14/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4535 - accuracy: 0.7962
# Epoch 15/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4554 - accuracy: 0.7848
# Epoch 16/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4496 - accuracy: 0.7933
# Epoch 17/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4393 - accuracy: 0.8017
# Epoch 18/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4578 - accuracy: 0.7873
# Epoch 19/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4241 - accuracy: 0.8096
# Epoch 20/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4453 - accuracy: 0.7949
# Epoch 21/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4435 - accuracy: 0.7988
# Epoch 22/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4430 - accuracy: 0.7899
# Epoch 23/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4250 - accuracy: 0.8070
# Epoch 24/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4343 - accuracy: 0.7957
# Epoch 25/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4280 - accuracy: 0.8028
# Epoch 26/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4275 - accuracy: 0.8037
# Epoch 27/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4210 - accuracy: 0.8069
# Epoch 28/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4291 - accuracy: 0.8045: 0s - loss: 0.4293 - accuracy: 0.80
# Epoch 29/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4291 - accuracy: 0.8043: 0s - loss: 0.4321 - accu
# Epoch 30/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4263 - accuracy: 0.7998
# Epoch 31/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4265 - accuracy: 0.8061
# Epoch 32/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4252 - accuracy: 0.8036
# Epoch 33/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4233 - accuracy: 0.8061
# Epoch 34/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4192 - accuracy: 0.8078
# Epoch 35/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4200 - accuracy: 0.8067
# Epoch 36/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4037 - accuracy: 0.8159
# Epoch 37/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4142 - accuracy: 0.8125
# Epoch 38/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4121 - accuracy: 0.8093
# Epoch 39/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4089 - accuracy: 0.8142
# Epoch 40/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4117 - accuracy: 0.8135
# Epoch 41/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4114 - accuracy: 0.8144
# Epoch 42/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4128 - accuracy: 0.8075
# Epoch 43/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3956 - accuracy: 0.8177
# Epoch 44/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4081 - accuracy: 0.8141
# Epoch 45/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3967 - accuracy: 0.8247
# Epoch 46/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4142 - accuracy: 0.8086
# Epoch 47/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4083 - accuracy: 0.8109
# Epoch 48/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3993 - accuracy: 0.8217
# Epoch 49/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3980 - accuracy: 0.8196
# Epoch 50/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3998 - accuracy: 0.8179
# Epoch 51/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3931 - accuracy: 0.8218
# Epoch 52/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3991 - accuracy: 0.8109
# Epoch 53/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3951 - accuracy: 0.8256
# Epoch 54/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3905 - accuracy: 0.8272
# Epoch 55/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3958 - accuracy: 0.8246
# Epoch 56/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4040 - accuracy: 0.8153
# Epoch 57/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3909 - accuracy: 0.8221
# Epoch 58/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3924 - accuracy: 0.8199
# Epoch 59/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3979 - accuracy: 0.8213
# Epoch 60/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3952 - accuracy: 0.8266
# Epoch 61/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3952 - accuracy: 0.8212
# Epoch 62/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3920 - accuracy: 0.8254
# Epoch 63/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3888 - accuracy: 0.8265
# Epoch 64/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3925 - accuracy: 0.8269
# Epoch 65/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3898 - accuracy: 0.8216
# Epoch 66/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3826 - accuracy: 0.8346
# Epoch 67/100
# 259/259 [==============================] - 1s 4ms/step - loss: 0.3832 - accuracy: 0.8241
# Epoch 68/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.3925 - accuracy: 0.8233
# Epoch 69/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.3807 - accuracy: 0.8262
# Epoch 70/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3837 - accuracy: 0.8292
# Epoch 71/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3835 - accuracy: 0.8277
# Epoch 72/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3765 - accuracy: 0.8355
# Epoch 73/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3898 - accuracy: 0.8265
# Epoch 74/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3807 - accuracy: 0.8337
# Epoch 75/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3700 - accuracy: 0.8358
# Epoch 76/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3832 - accuracy: 0.8318
# Epoch 77/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3793 - accuracy: 0.8309
# Epoch 78/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3759 - accuracy: 0.8358
# Epoch 79/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3761 - accuracy: 0.8323
# Epoch 80/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3753 - accuracy: 0.8348
# Epoch 81/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3731 - accuracy: 0.8314
# Epoch 82/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3735 - accuracy: 0.8316
# Epoch 83/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3691 - accuracy: 0.8397
# Epoch 84/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3699 - accuracy: 0.8391
# Epoch 85/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3660 - accuracy: 0.8392
# Epoch 86/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3672 - accuracy: 0.8411
# Epoch 87/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3707 - accuracy: 0.8399
# Epoch 88/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3743 - accuracy: 0.8332
# Epoch 89/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3814 - accuracy: 0.8298: 0s - loss: 0.3871 -
# Epoch 90/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3701 - accuracy: 0.8338
# Epoch 91/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3684 - accuracy: 0.8356
# Epoch 92/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3844 - accuracy: 0.8309
# Epoch 93/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3705 - accuracy: 0.8405
# Epoch 94/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3676 - accuracy: 0.8353
# Epoch 95/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3617 - accuracy: 0.8435
# Epoch 96/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3636 - accuracy: 0.8428
# Epoch 97/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3675 - accuracy: 0.8418
# Epoch 98/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3646 - accuracy: 0.8389
# Epoch 99/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3550 - accuracy: 0.8482
# Epoch 100/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.3648 - accuracy: 0.8413
# 65/65 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7861
# [0.47651877999305725, 0.7860600352287292]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79      1033
#            1       0.78      0.79      0.79      1033
#
#     accuracy                           0.79      2066
#    macro avg       0.79      0.79      0.79      2066
# weighted avg       0.79      0.79      0.79      2066

# %% [markdown]
# Check classification report above. f1-score for minority class 1 improved from 0.57 to 0.76. Score for class 0 reduced to 0.75 from 0.85 but that's ok. We have more generalized classifier which classifies both classes with similar prediction score

# %% [markdown]
# ### Method3: SMOTE
#
# To install imbalanced-learn library use `pip install imbalanced-learn ` command

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.8.0-py3-none-any.whl (206 kB)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\basto\anaconda3\envs\tfgpu\lib\site-packages (from imbalanced-learn) (1.6.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\basto\anaconda3\envs\tfgpu\lib\site-packages (from imbalanced-learn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\basto\anaconda3\envs\tfgpu\lib\site-packages (from imbalanced-learn) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\basto\anaconda3\envs\tfgpu\lib\site-packages (from imbalanced-learn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\basto\anaconda3\envs\tfgpu\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.8.0

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_sample(X, y)

y_sm.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-6816be3918b4> in <module>
#       2
#       3 smote = SMOTE(sampling_strategy='minority')
# ----> 4 X_sm, y_sm = smote.fit_sample(X, y)
#       5
#       6 y_sm.value_counts()
#
# AttributeError: 'SMOTE' object has no attribute 'fit_sample'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-042d068ac2aa> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)
#
# NameError: name 'X_sm' is not defined

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c0dbf9497398> in <module>
#       1 # Number of classes in training Data
# ----> 2 y_train.value_counts()
#
# NameError: name 'y_train' is not defined

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d953d6e39109> in <module>
# ----> 1 y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
#
# NameError: name 'ANN' is not defined

# %% [markdown]
# SMOT Oversampling increases f1 score of minority class 1 from 0.57 to 0.81 (huge improvement) Also over all accuracy improves from 0.78 to 0.80

# %% [markdown]
# ### Method4: Use of Ensemble with undersampling

# %%
df2.Churn.value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
# Regain Original features and labels
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0    4130
# 1    1495
# Name: Churn, dtype: int64

# %%
df3 = X_train.copy()
df3['Churn'] = y_train

# %%
df3.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 684        1              0        0           0  0.000000             1
# 2446       1              0        0           0  0.239437             1
# 1680       0              0        1           1  0.774648             1
# 2220       0              0        1           0  1.000000             1
# 2842       1              0        0           0  0.042254             0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 684               0               0             0                 0  ...
# 2446              1               0             1                 0  ...
# 1680              1               0             0                 0  ...
# 2220              0               1             1                 0  ...
# 2842              0               1             0                 1  ...
#
#       InternetService_Fiber optic  InternetService_No  \
# 684                             1                   0
# 2446                            1                   0
# 1680                            0                   1
# 2220                            0                   0
# 2842                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 684                         1                  0                  0
# 2446                        1                  0                  0
# 1680                        0                  1                  0
# 2220                        0                  0                  1
# 2842                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 684                                         0
# 2446                                        0
# 1680                                        0
# 2220                                        1
# 2842                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 684                                       0                               0
# 2446                                      1                               0
# 1680                                      0                               0
# 2220                                      0                               0
# 2842                                      0                               0
#
#       PaymentMethod_Mailed check  Churn
# 684                            1      0
# 2446                           0      1
# 1680                           1      0
# 2220                           0      0
# 2842                           1      0
#
# [5 rows x 27 columns]

# %%
df3_class0 = df3[df3.Churn==0]
df3_class1 = df3[df3.Churn==1]

# %%
def get_train_batch(df_majority, df_minority, start, end):
    df_train = pd.concat([df_majority[start:end], df_minority], axis=0)

    X_train = df_train.drop('Churn', axis='columns')
    y_train = df_train.Churn
    return X_train, y_train

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 0, 1495)

y_pred1 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 3ms/step - loss: 0.6980 - accuracy: 0.5109
# Epoch 2/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5716 - accuracy: 0.7413
# Epoch 3/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5005 - accuracy: 0.7575
# Epoch 4/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7502
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4953 - accuracy: 0.7604
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4953 - accuracy: 0.7580
# Epoch 7/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4852 - accuracy: 0.7651
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4868 - accuracy: 0.7655
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.7849
# Epoch 10/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4659 - accuracy: 0.7826
# Epoch 11/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4949 - accuracy: 0.7562
# Epoch 12/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.7898
# Epoch 13/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4696 - accuracy: 0.7730
# Epoch 14/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4750 - accuracy: 0.7693
# Epoch 15/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4687 - accuracy: 0.7714
# Epoch 16/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4693 - accuracy: 0.7764
# Epoch 17/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.7741
# Epoch 18/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4716 - accuracy: 0.7748
# Epoch 19/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4620 - accuracy: 0.7825
# Epoch 20/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4669 - accuracy: 0.7762
# Epoch 21/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4516 - accuracy: 0.7869
# Epoch 22/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4689 - accuracy: 0.7736
# Epoch 23/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4561 - accuracy: 0.7812
# Epoch 24/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.7788
# Epoch 25/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4503 - accuracy: 0.7852
# Epoch 26/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4710 - accuracy: 0.7760
# Epoch 27/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4642 - accuracy: 0.7824
# Epoch 28/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4471 - accuracy: 0.7915
# Epoch 29/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4451 - accuracy: 0.7881
# Epoch 30/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4508 - accuracy: 0.7840
# Epoch 31/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.7905
# Epoch 32/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4530 - accuracy: 0.7865
# Epoch 33/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.7928
# Epoch 34/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4326 - accuracy: 0.7895
# Epoch 35/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.7914
# Epoch 36/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.7938
# Epoch 37/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4400 - accuracy: 0.7923
# Epoch 38/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.7958
# Epoch 39/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4275 - accuracy: 0.8022
# Epoch 40/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8000
# Epoch 41/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4394 - accuracy: 0.7851
# Epoch 42/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.8097
# Epoch 43/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4379 - accuracy: 0.7913
# Epoch 44/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4387 - accuracy: 0.7933
# Epoch 45/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4225 - accuracy: 0.8029
# Epoch 46/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4274 - accuracy: 0.8017
# Epoch 47/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4090 - accuracy: 0.8193
# Epoch 48/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4188 - accuracy: 0.7998
# Epoch 49/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.4224 - accuracy: 0.8018
# Epoch 50/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.7966
# Epoch 51/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4228 - accuracy: 0.8081
# Epoch 52/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.8031
# Epoch 53/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8121
# Epoch 54/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4296 - accuracy: 0.7934
# Epoch 55/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.8171
# Epoch 56/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4116 - accuracy: 0.8137
# Epoch 57/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4300 - accuracy: 0.7996
# Epoch 58/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4115 - accuracy: 0.8065
# Epoch 59/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.8061
# Epoch 60/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4012 - accuracy: 0.8174
# Epoch 61/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4171 - accuracy: 0.8064
# Epoch 62/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3973 - accuracy: 0.8181
# Epoch 63/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4075 - accuracy: 0.8061
# Epoch 64/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3985 - accuracy: 0.8147
# Epoch 65/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4033 - accuracy: 0.8112
# Epoch 66/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8126
# Epoch 67/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4040 - accuracy: 0.8074
# Epoch 68/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8063
# Epoch 69/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3817 - accuracy: 0.8297
# Epoch 70/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3967 - accuracy: 0.8260
# Epoch 71/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3744 - accuracy: 0.8345
# Epoch 72/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3904 - accuracy: 0.8136
# Epoch 73/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8182
# Epoch 74/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3809 - accuracy: 0.8295
# Epoch 75/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3810 - accuracy: 0.8375
# Epoch 76/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3922 - accuracy: 0.8166
# Epoch 77/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3912 - accuracy: 0.8227
# Epoch 78/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3980 - accuracy: 0.8171
# Epoch 79/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3798 - accuracy: 0.8249
# Epoch 80/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8235
# Epoch 81/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.8244
# Epoch 82/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3847 - accuracy: 0.8229
# Epoch 83/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3732 - accuracy: 0.8224
# Epoch 84/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3768 - accuracy: 0.8297
# Epoch 85/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3849 - accuracy: 0.8204
# Epoch 86/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3732 - accuracy: 0.8303
# Epoch 87/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8062
# Epoch 88/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3788 - accuracy: 0.8340
# Epoch 89/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.8229
# Epoch 90/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3700 - accuracy: 0.8362
# Epoch 91/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3701 - accuracy: 0.8277
# Epoch 92/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3800 - accuracy: 0.8287
# Epoch 93/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3889 - accuracy: 0.8233
# Epoch 94/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4011 - accuracy: 0.8152
# Epoch 95/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8272
# Epoch 96/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3813 - accuracy: 0.8308
# Epoch 97/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3777 - accuracy: 0.8276
# Epoch 98/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3665 - accuracy: 0.8369
# Epoch 99/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3847 - accuracy: 0.8305
# Epoch 100/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3704 - accuracy: 0.8279
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.7299
# [0.5706118941307068, 0.729921817779541]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.72      0.80      1033
#            1       0.49      0.76      0.60       374
#
#     accuracy                           0.73      1407
#    macro avg       0.69      0.74      0.70      1407
# weighted avg       0.79      0.73      0.74      1407

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 1495, 2990)

y_pred2 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 3ms/step - loss: 0.6556 - accuracy: 0.6231
# Epoch 2/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5256 - accuracy: 0.7509
# Epoch 3/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5242 - accuracy: 0.7468
# Epoch 4/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4705 - accuracy: 0.7790
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.7568
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4788 - accuracy: 0.7634
# Epoch 7/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.4661 - accuracy: 0.7871
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7715
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4740 - accuracy: 0.7730
# Epoch 10/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4799 - accuracy: 0.7679: 0s - loss: 0.4834 - accuracy:
# Epoch 11/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4787 - accuracy: 0.7682
# Epoch 12/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4746 - accuracy: 0.7636
# Epoch 13/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.7657
# Epoch 14/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.7752
# Epoch 15/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4796 - accuracy: 0.7567
# Epoch 16/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4682 - accuracy: 0.7693: 0s - loss: 0.4685 - accuracy: 0.76
# Epoch 17/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4706 - accuracy: 0.7654
# Epoch 18/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4643 - accuracy: 0.7629
# Epoch 19/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4680 - accuracy: 0.7649
# Epoch 20/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4728 - accuracy: 0.7692
# Epoch 21/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.7862
# Epoch 22/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.7804
# Epoch 23/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7670
# Epoch 24/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4583 - accuracy: 0.7749
# Epoch 25/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4477 - accuracy: 0.7733
# Epoch 26/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4452 - accuracy: 0.7848
# Epoch 27/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.7900
# Epoch 28/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4509 - accuracy: 0.7741
# Epoch 29/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 0.7913
# Epoch 30/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4378 - accuracy: 0.7858
# Epoch 31/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4394 - accuracy: 0.7907
# Epoch 32/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4344 - accuracy: 0.7998
# Epoch 33/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4232 - accuracy: 0.7925
# Epoch 34/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4194 - accuracy: 0.7886: 0s - loss: 0.4095 - accuracy
# Epoch 35/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4395 - accuracy: 0.7893
# Epoch 36/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.7894
# Epoch 37/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4238 - accuracy: 0.7888
# Epoch 38/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.8045
# Epoch 39/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.7922
# Epoch 40/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.7810
# Epoch 41/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4220 - accuracy: 0.7930
# Epoch 42/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4320 - accuracy: 0.7843
# Epoch 43/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.7895
# Epoch 44/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.7914
# Epoch 45/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.7938
# Epoch 46/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4243 - accuracy: 0.7978
# Epoch 47/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4187 - accuracy: 0.8033
# Epoch 48/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4130 - accuracy: 0.8074
# Epoch 49/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4291 - accuracy: 0.7951
# Epoch 50/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.7998
# Epoch 51/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8075
# Epoch 52/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4022 - accuracy: 0.8084
# Epoch 53/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4171 - accuracy: 0.7990
# Epoch 54/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4025 - accuracy: 0.8054
# Epoch 55/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4118 - accuracy: 0.7997
# Epoch 56/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4045 - accuracy: 0.8079
# Epoch 57/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4065 - accuracy: 0.8130
# Epoch 58/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4099 - accuracy: 0.7988
# Epoch 59/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8026
# Epoch 60/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4083 - accuracy: 0.8007
# Epoch 61/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.7947
# Epoch 62/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.3928 - accuracy: 0.8098
# Epoch 63/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8089
# Epoch 64/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3912 - accuracy: 0.8108
# Epoch 65/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4063 - accuracy: 0.8084
# Epoch 66/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4021 - accuracy: 0.8123
# Epoch 67/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3902 - accuracy: 0.8166
# Epoch 68/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3911 - accuracy: 0.8149
# Epoch 69/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.8040
# Epoch 70/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4006 - accuracy: 0.8073
# Epoch 71/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.8048
# Epoch 72/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3908 - accuracy: 0.8156
# Epoch 73/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3876 - accuracy: 0.8249
# Epoch 74/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.8164
# Epoch 75/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8196
# Epoch 76/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3998 - accuracy: 0.8095
# Epoch 77/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3842 - accuracy: 0.8136
# Epoch 78/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4033 - accuracy: 0.8120
# Epoch 79/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8119
# Epoch 80/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3941 - accuracy: 0.8130
# Epoch 81/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3982 - accuracy: 0.8073
# Epoch 82/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3893 - accuracy: 0.8124
# Epoch 83/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.8158
# Epoch 84/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.8183
# Epoch 85/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3727 - accuracy: 0.8131
# Epoch 86/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3930 - accuracy: 0.8043
# Epoch 87/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8090
# Epoch 88/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3849 - accuracy: 0.8168
# Epoch 89/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8206
# Epoch 90/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3704 - accuracy: 0.8274
# Epoch 91/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 0.8354
# Epoch 92/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3840 - accuracy: 0.8225
# Epoch 93/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3808 - accuracy: 0.8187
# Epoch 94/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.8180
# Epoch 95/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3750 - accuracy: 0.8202
# Epoch 96/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8263
# Epoch 97/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3710 - accuracy: 0.8274
# Epoch 98/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8226
# Epoch 99/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3883 - accuracy: 0.8117
# Epoch 100/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3708 - accuracy: 0.8316
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5988 - accuracy: 0.7093
# [0.5988168716430664, 0.7093105912208557]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77      1033
#            1       0.47      0.80      0.60       374
#
#     accuracy                           0.71      1407
#    macro avg       0.69      0.74      0.68      1407
# weighted avg       0.79      0.71      0.73      1407

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 2990, 4130)

y_pred3 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 83/83 [==============================] - 1s 3ms/step - loss: 0.6888 - accuracy: 0.5793
# Epoch 2/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.7568
# Epoch 3/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4924 - accuracy: 0.7591
# Epoch 4/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4885 - accuracy: 0.7684
# Epoch 5/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4790 - accuracy: 0.7747
# Epoch 6/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.7742
# Epoch 7/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.7747
# Epoch 8/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4749 - accuracy: 0.7781
# Epoch 9/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4861 - accuracy: 0.7708
# Epoch 10/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4665 - accuracy: 0.7735
# Epoch 11/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4706 - accuracy: 0.7790
# Epoch 12/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7970
# Epoch 13/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.7979
# Epoch 14/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4616 - accuracy: 0.7821
# Epoch 15/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.7981
# Epoch 16/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4650 - accuracy: 0.7818
# Epoch 17/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4654 - accuracy: 0.7792
# Epoch 18/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4552 - accuracy: 0.7797
# Epoch 19/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4563 - accuracy: 0.7838
# Epoch 20/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.7914
# Epoch 21/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4627 - accuracy: 0.7835
# Epoch 22/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4479 - accuracy: 0.7923
# Epoch 23/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4333 - accuracy: 0.7974
# Epoch 24/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4464 - accuracy: 0.7938
# Epoch 25/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4574 - accuracy: 0.7850
# Epoch 26/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4586 - accuracy: 0.7848
# Epoch 27/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4344 - accuracy: 0.8044
# Epoch 28/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.8012
# Epoch 29/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.7893
# Epoch 30/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4364 - accuracy: 0.7917
# Epoch 31/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4385 - accuracy: 0.7947
# Epoch 32/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.8101
# Epoch 33/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4343 - accuracy: 0.7966: 0s - loss: 0.4356 - accuracy:
# Epoch 34/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.7983
# Epoch 35/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4391 - accuracy: 0.7998
# Epoch 36/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.8051
# Epoch 37/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.7999
# Epoch 38/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.8020
# Epoch 39/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.8039
# Epoch 40/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4160 - accuracy: 0.8205
# Epoch 41/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4356 - accuracy: 0.8033
# Epoch 42/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.7955
# Epoch 43/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4233 - accuracy: 0.8054
# Epoch 44/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8066
# Epoch 45/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4132 - accuracy: 0.8117
# Epoch 46/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8138
# Epoch 47/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.8062
# Epoch 48/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.8096
# Epoch 49/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4272 - accuracy: 0.7970
# Epoch 50/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4164 - accuracy: 0.7988
# Epoch 51/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4096 - accuracy: 0.8130
# Epoch 52/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3938 - accuracy: 0.8207
# Epoch 53/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4217 - accuracy: 0.7966
# Epoch 54/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3959 - accuracy: 0.8073
# Epoch 55/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.8220
# Epoch 56/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3803 - accuracy: 0.8330
# Epoch 57/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4099 - accuracy: 0.8169
# Epoch 58/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4005 - accuracy: 0.8149
# Epoch 59/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.8038
# Epoch 60/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3848 - accuracy: 0.8272
# Epoch 61/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.8143
# Epoch 62/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3986 - accuracy: 0.8226
# Epoch 63/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3918 - accuracy: 0.8203
# Epoch 64/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.8169
# Epoch 65/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3887 - accuracy: 0.8202
# Epoch 66/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3971 - accuracy: 0.8122
# Epoch 67/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3782 - accuracy: 0.8319
# Epoch 68/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3960 - accuracy: 0.8190
# Epoch 69/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3889 - accuracy: 0.8156
# Epoch 70/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3844 - accuracy: 0.8324
# Epoch 71/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3974 - accuracy: 0.8171
# Epoch 72/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3964 - accuracy: 0.8187
# Epoch 73/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8234
# Epoch 74/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3738 - accuracy: 0.8245
# Epoch 75/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4024 - accuracy: 0.8080
# Epoch 76/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3852 - accuracy: 0.8274
# Epoch 77/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3594 - accuracy: 0.8377
# Epoch 78/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.8157
# Epoch 79/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3773 - accuracy: 0.8309
# Epoch 80/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3795 - accuracy: 0.8335
# Epoch 81/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3721 - accuracy: 0.8340
# Epoch 82/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3811 - accuracy: 0.8259
# Epoch 83/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3893 - accuracy: 0.8281: 0s - loss: 0.3943 - accuracy
# Epoch 84/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3907 - accuracy: 0.8213
# Epoch 85/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3642 - accuracy: 0.8408
# Epoch 86/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8311
# Epoch 87/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.8200
# Epoch 88/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3862 - accuracy: 0.8194
# Epoch 89/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3675 - accuracy: 0.8374
# Epoch 90/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8226
# Epoch 91/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3715 - accuracy: 0.8277
# Epoch 92/100
# 83/83 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8240
# Epoch 93/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3691 - accuracy: 0.8313
# Epoch 94/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.8375
# Epoch 95/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8319
# Epoch 96/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3761 - accuracy: 0.8263
# Epoch 97/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.8371
# Epoch 98/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3776 - accuracy: 0.8333
# Epoch 99/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3640 - accuracy: 0.8282
# Epoch 100/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.3450 - accuracy: 0.8471
# 44/44 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.6667
# [0.6604515314102173, 0.6666666865348816]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.62      0.73      1033
#            1       0.43      0.80      0.56       374
#
#     accuracy                           0.67      1407
#    macro avg       0.66      0.71      0.65      1407
# weighted avg       0.77      0.67      0.69      1407

# %%
len(y_pred1)
# Out:
# 1407

# %%
y_pred_final = y_pred1.copy()
for i in range(len(y_pred1)):
    n_ones = y_pred1[i] + y_pred2[i] + y_pred3[i]
    if n_ones>1:
        y_pred_final[i] = 1
    else:
        y_pred_final[i] = 0

# %%
cl_rep = classification_report(y_test, y_pred_final)
print(cl_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77      1033
#            1       0.47      0.80      0.59       374
#
#     accuracy                           0.70      1407
#    macro avg       0.69      0.74      0.68      1407
# weighted avg       0.79      0.70      0.72      1407

# %% [markdown]
# f1-score for minority class 1 improved to 0.62 from 0.57. The score for majority class 0 is suffering and reduced to 0.80 from 0.85 but at least there is some balance in terms of prediction accuracy across two classes
